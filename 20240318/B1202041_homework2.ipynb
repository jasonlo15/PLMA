# %%
a='C,B,A'
b=['F','G','H']
a=a.split(',')
a.extend(b)
a[0]='K'
print(a.pop(2))
del  a[1:4]
a.append('U')
print(a)
# Out:
# A
# ['K', 'H', 'U']

# %%
x=input("8 digit")
print(x[4:5])
# Out:
# 8 digit12321321321
# 1

# %%
a='My ID is B1202041'
a=a.split()
print(len(a),len(a[3][0:]))
# Out:
# 4 8

# %%
a="I\'m a student"
a=a.split()
print(a[0][2])
# Out:
# m
